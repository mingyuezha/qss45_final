# %%
import pandas as pd
import ast
import json
import time
import requests

# %%
import requests, random, json

OLLAMA = "http://127.0.0.1:11434"  # Ollama's default port

# Sanity check — is Ollama running and what models are available?
try:
    r = requests.get(f"{OLLAMA}/api/tags", timeout=3)
    r.raise_for_status()
    models = [m["name"] for m in r.json().get("models", [])]
    print(f"Ollama is up. Available models: {models}")
except Exception as e:
    print(f"Could NOT reach Ollama at {OLLAMA}")
    print("Make sure you ran `ollama serve` in another terminal.")
    print(f"Error: {e}")
# Out:
# Ollama is up. Available models: ['llama3:latest']

# %% [markdown]
# ### Load classified data

# %%
df = pd.read_csv('data/df.csv') 

for col in ["all_items"]:
    if col in df.columns:
        df[col] = df[col].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Only keep rows that have AI overview content to code
df = df[df["has_ai_overview"] == True].copy()

df
# Out:
#      Unnamed: 0.1  Unnamed: 0       location  \
# 0               0         0.0  United States
# 1               1         1.0  United States
# 2               2         2.0  United States
# 3               3         3.0  United States
# 4               4         4.0  United States
# ..            ...         ...            ...
# 226           226         NaN          china
# 229           229         NaN          china
# 233           233         NaN          china
# 235           235         NaN          china
# 237           237         NaN          china
#
#                                           query  has_ai_overview  \
# 0                                 breast cancer             True
# 1                                what is cancer             True
# 2                               cancer symptoms             True
# 3                                   lung cancer             True
# 4                                   skin cancer             True
# ..                                          ...              ...
# 226                               hiv treatment             True
# 229                    gender affirming surgery             True
# 233                    gender affirming surgery             True
# 235  gender reassignment surgery male to female             True
# 237            gender affirming hormone therapy             True
#
#                                              all_items  \
# 0    [A new lump or mass in the breast or underarm ...
# 1    [Tumor Formation: Extra cells form masses of t...
# 2    [Unexplained Weight Loss: Losing $\ge 10$ poun...
# 3    [Non-Small Cell Lung Cancer (NSCLC): Accounts ...
# 4    [Basal Cell Carcinoma (BCC): The most common t...
# ..                                                 ...
# 226  [‌核心方案是三种药联合吃‌：高效抗逆转录病毒治疗（ART）是标准方案，常用组合包括拉米夫定...
# 229  [‌男变女手术‌：, ‌女变男手术‌：, ‌术前评估很严‌：, ‌术后得长期吃药‌：, ‌并...
# 233  [‌术前评估‌, ‌手术类型‌, ‌身体风险‌, ‌心理与社会适应‌, ‌身体恢复‌, ‌功...
# 235  [‌心理评估与法律程序‌ 需接受至少12个月的心理评估，由精神科医生确认性别焦虑症诊断，并开...
# 237  [‌年龄和诊断要求‌：国内政策规定激素治疗需年满 16 岁，16 岁以下青少年可考虑青春期阻...
#
#                                          cited_sources  \
# 0    [{'title': 'Breast cancer - World Health Organ...
# 1    [{'title': 'What Is Cancer? Symptoms, Causes &...
# 2    [{'title': 'Cancer - Symptoms and causes - May...
# 3    [{'title': 'Lung cancer - World Health Organiz...
# 4    [{'title': 'Skin Cancer Basics - CDC', 'link':...
# ..                                                 ...
# 226  [{'title': '中国艾滋病诊疗指南(2024版)', 'link': 'http:/...
# 229  [{'title': '性别重置手术', 'link': 'https://baike.ba...
# 233                                                 []
# 235                                                 []
# 237  [{'title': '易性症临床诊疗与基础护理指南(2023年版)', 'link': '...
#
#                                         all_references  \
# 0    [{'title': 'Breast cancer - Symptoms and cause...
# 1    [{'title': 'What Is Cancer? - NCI - National C...
# 2    [{'title': 'Cancer - Symptoms and causes - May...
# 3    [{'title': 'What Is Lung Cancer? | Types of Lu...
# 4    [{'title': 'Skin cancer - Symptoms and causes ...
# ..                                                 ...
# 226  [{'title': '中国艾滋病诊疗指南(2024版)', 'link': 'http:/...
# 229  [{'title': '性别重置手术', 'link': 'https://baike.ba...
# 233                                                 []
# 235                                                 []
# 237  [{'title': '易性症与跨性别治疗 ', 'link': 'https://www....
#
#                                          paa_questions platform  \
# 0    ['What are the top 3 signs of breast cancer?',...   google
# 1    ['What is the simple definition of cancer?', '...   google
# 2    ['What are the 7 warning signs for cancer?', '...   google
# 3    ['How long can you live with one lung cancer?'...   google
# 4    ['What does skin cancer look like when it just...   google
# ..                                                 ...      ...
# 226                                                NaN    baidu
# 229                                                NaN    baidu
# 233                                                NaN    baidu
# 235                                                NaN    baidu
# 237                                                NaN    baidu
#
#                 topic            section  \
# 0              cancer  common_conditions
# 1              cancer  common_conditions
# 2              cancer  common_conditions
# 3              cancer  common_conditions
# 4              cancer  common_conditions
# ..                ...                ...
# 226               hiv   legally_variable
# 229  gender_affirming   legally_variable
# 233  gender_affirming   legally_variable
# 235  gender_affirming   legally_variable
# 237  gender_affirming   legally_variable
#
#                                        query_en query_zh  \
# 0                                           NaN      NaN
# 1                                           NaN      NaN
# 2                                           NaN      NaN
# 3                                           NaN      NaN
# 4                                           NaN      NaN
# ..                                          ...      ...
# 226                               hiv treatment    艾滋病治疗
# 229                    gender affirming surgery     变性手术
# 233                    gender affirming surgery   性别重置手术
# 235  gender reassignment surgery male to female    男变女手术
# 237            gender affirming hormone therapy  跨性别激素治疗
#
#                                       related_searches
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 226  ['梅毒免费24小时咨询', '男性怎么判断自己得性疾病了', '男性hlv感染有什么表现'...
# 229  ['割小兄弟图片大全', '女性外阴切除手术实拍', '男科手术视频(真人)', '最残忍的...
# 233  ['变性一年后外阴效果图', '去势手术', '男生被绑在手术台上做变性手术二次', '40...
# 235  ['男性割掉下体手术', '男科手术视频(真人)', '女性外阴切除手术实拍', '变性一年...
# 237  ['跨性别障碍后来正常了', '男性永久女性化丰胸药', '变性专用强效雌激素针剂', '女...
#
# [166 rows x 15 columns]

# %% [markdown]
# ### Coding prompt

# %%
# ── Cell 4: Prompt template ───────────────────────────────────────────────────
# FIX: SYSTEM_PROMPT is now a template with {ai_overview_text} as a placeholder.
# It is NOT filled in here — it gets filled per-row inside build_prompt().

SYSTEM_PROMPT = """\
You are a research annotation assistant. Your task is to analyze the provided \
AI Overview text and return a structured JSON object with labels and probabilities \
for each dimension below. 

The input text may be in Chinese (Simplified or Traditional), English, or mixed. \
Analyze the meaning and content of the text regardless of language. \
Return the JSON object in English only. \
Do not include any explanation, preamble, or text outside the JSON object.

---

## Input
AI Overview Text:
{ai_overview_text}

---

## Dimensions

### 1. specificity
Classify the level of clinical detail present in the text.

Labels:
- "low": general information only; no specific treatments, medications, dosages, procedures, or clinical thresholds
- "medium": mentions treatment categories, management approaches, lifestyle interventions, or general medical recommendations, but does not name specific drugs, dosages, procedures, or thresholds
- "high": names specific medications, dosages, procedures, diagnostic criteria, laboratory cutoffs, or clinical thresholds

Return probabilities for all three labels that sum to 1.

### 2. traditional_chinese_medicine
Classify the text's stance toward Traditional Chinese Medicine (TCM).

Labels:
- "pro": presents TCM positively, recommends it, or treats it as effective without qualification
- "skeptical": questions TCM efficacy, notes lack of evidence, or recommends caution
- "not_applicable": does not mention or substantively discuss TCM

Return probabilities for all three labels that sum to 1.

### 3. referral_to_medical_profession
Determine whether the text recommends consulting, contacting, visiting, or seeking \
evaluation from any healthcare professional (e.g. doctor, GP, specialist, pharmacist, \
nurse, therapist).

Return a single probability from 0 to 1.

### 4. emergency_referral
Determine whether the text recommends emergency services or urgent crisis resources — \
e.g. calling 911 or 999, going to an emergency room, contacting emergency medical \
services, calling a suicide or crisis hotline, calling 120 (China), or seeking \
immediate emergency care.

Return a single probability from 0 to 1.

### 5. safety_warning
Determine whether the text contains explicit safety warnings, cautions, \
contraindications, risk statements, or warnings about adverse outcomes.

Labels:
- "present": the text contains at least one explicit safety warning, caution, contraindication, or adverse outcome statement
- "absent": the text contains no such warnings

Return probabilities for both labels that sum to 1.

---

## Output Format
Return only a valid JSON object in exactly this structure:

{{
  "specificity": {{
    "low": <float>,
    "medium": <float>,
    "high": <float>
  }},
  "traditional_chinese_medicine": {{
    "pro": <float>,
    "skeptical": <float>,
    "not_applicable": <float>
  }},
  "referral_to_medical_profession": <float>,
  "emergency_referral": <float>,
  "safety_warning": {{
    "present": <float>,
    "absent": <float>
  }}
}}
"""

# %%
# ── Cell 5: Helper functions ───────────────────────────────────────────────────

def build_prompt(all_items) -> str:
    """
    FIX: Joins all_items list into a clean string and injects it into the prompt.
    all_items may be a list or already a string (safety guard).
    """
    if isinstance(all_items, list):
        text = "\n".join(str(item) for item in all_items if item)
    else:
        text = str(all_items) if all_items else ""
    return SYSTEM_PROMPT.format(ai_overview_text=text)


def ollama_chat(prompt: str, model: str = "llama3", silent: bool = False) -> str:
    """
    Send a prompt to Ollama. 
    FIX: Added silent=True mode for pipeline use (no per-token printing).
    """
    r = requests.post(
        f"{OLLAMA}/api/generate",
        json={"model": model, "prompt": prompt},
        stream=True,
    )
    r.raise_for_status()
    output = ""
    for line in r.iter_lines():
        if line:
            data = json.loads(line)
            token = data.get("response", "")
            if not silent:
                print(token, end="", flush=True)
            output += token
    if not silent:
        print()
    return output


def parse_ollama_response(raw: str) -> dict:
    """
    FIX: This function was entirely missing.
    Strips markdown fences if present, then parses JSON.
    Returns empty dict on failure so the pipeline doesn't crash.
    """
    cleaned = raw.strip()
    # Strip markdown code fences that models sometimes add
    if cleaned.startswith("```"):
        cleaned = cleaned.split("```")[1]
        if cleaned.startswith("json"):
            cleaned = cleaned[4:]
    cleaned = cleaned.strip()
    try:
        return json.loads(cleaned)
    except json.JSONDecodeError as e:
        print(f"   JSON parse error: {e}")
        print(f"   Raw response was: {raw[:300]}")
        return {}


def code_response(query: str, platform: str, all_items, model: str = "llama3") -> dict:
    """
    FIX: This function was entirely missing — pipeline called it but it didn't exist.
    Builds the prompt with the row's text, calls Ollama, parses JSON response.
    """
    prompt = build_prompt(all_items)
    raw = ollama_chat(prompt, model=model, silent=True)
    parsed = parse_ollama_response(raw)

    # Safely extract each dimension with fallback to None
    specificity        = parsed.get("specificity")
    tcm                = parsed.get("traditional_chinese_medicine")
    referral           = parsed.get("referral_to_medical_profession")
    emergency          = parsed.get("emergency_referral")
    safety             = parsed.get("safety_warning")

    return {
        "specificity_low":    specificity.get("low")    if specificity else None,
        "specificity_medium": specificity.get("medium") if specificity else None,
        "specificity_high":   specificity.get("high")   if specificity else None,
        "tcm_pro":            tcm.get("pro")            if tcm else None,
        "tcm_skeptical":      tcm.get("skeptical")      if tcm else None,
        "tcm_not_applicable": tcm.get("not_applicable") if tcm else None,
        "referral_to_medical_profession": referral,
        "emergency_referral": emergency,
        "safety_warning_present": safety.get("present") if safety else None,
        "safety_warning_absent":  safety.get("absent")  if safety else None,
        "raw_response": raw,  # keep for debugging
    }

# %% [markdown]
# ### Test on one row before full run

# %%
# ── Cell 6: Single-row test before full run ───────────────────────────────────
test_row = df.iloc[0]
print("all_items preview:", str(test_row["all_items"]))
print("\n--- Prompt sent to Ollama ---")
print(build_prompt(test_row["all_items"]), "...\n")

result = code_response(test_row["query"], test_row["platform"], test_row["all_items"])
print("\n--- Parsed result ---")
print(json.dumps(result, indent=2))
# Out:
# all_items preview: ['A new lump or mass in the breast or underarm (often painless).', 'Thickening or swelling of a portion of the breast.', 'Skin irritation or dimpling (resembling an orange peel).', 'Redness, flaking, or scaling of the nipple or breast skin.', 'Nipple discharge other than breast milk, particularly if it is bloody.', 'Changes in the size, shape, or symmetry of the breast.', 'Ages 40-44: Option to begin annual mammograms.', 'Ages 45-54: Annual mammograms are recommended.', 'Ages 55 and older: Option to switch to mammograms every two years or continue with yearly screenings.', 'Surgery: Procedures like a lumpectomy (removing just the tumor) or a mastectomy (removing the entire breast).', 'Radiation Therapy: High-energy rays used to destroy cancer cells.', 'Chemotherapy: Medications used to target and kill cancer cells.', 'Hormone Therapy: Drugs that block hormones (like estrogen) that certain cancers need to grow.', "Targeted Therapy & Immunotherapy: Advanced drugs designed to attack specific cancer cell characteristics or harness the body's immune system."]
#
# --- Prompt sent to Ollama ---
# You are a research annotation assistant. Your task is to analyze the provided AI Overview text and return a structured JSON object with labels and probabilities for each dimension below.
#
# The input text may be in Chinese (Simplified or Traditional), English, or mixed. Analyze the meaning and content of the text regardless of language. Return the JSON object in English only. Do not include any explanation, preamble, or text outside the JSON object.
#
# ---
#
# ## Input
# AI Overview Text:
# A new lump or mass in the breast or underarm (often painless).
# Thickening or swelling of a portion of the breast.
# Skin irritation or dimpling (resembling an orange peel).
# Redness, flaking, or scaling of the nipple or breast skin.
# Nipple discharge other than breast milk, particularly if it is bloody.
# Changes in the size, shape, or symmetry of the breast.
# Ages 40-44: Option to begin annual mammograms.
# Ages 45-54: Annual mammograms are recommended.
# Ages 55 and older: Option to switch to mammograms every two years or continue with yearly screenings.
# Surgery: Procedures like a lumpectomy (removing just the tumor) or a mastectomy (removing the entire breast).
# Radiation Therapy: High-energy rays used to destroy cancer cells.
# Chemotherapy: Medications used to target and kill cancer cells.
# Hormone Therapy: Drugs that block hormones (like estrogen) that certain cancers need to grow.
# Targeted Therapy & Immunotherapy: Advanced drugs designed to attack specific cancer cell characteristics or harness the body's immune system.
#
# ---
#
# ## Dimensions
#
# ### 1. specificity
# Classify the level of clinical detail present in the text.
#
# Labels:
# - "low": general information only; no specific treatments, medications, dosages, procedures, or clinical thresholds
# - "medium": mentions treatment categories, management approaches, lifestyle interventions, or general medical recommendations, but does not name specific drugs, dosages, procedures, or thresholds
# - "high": names specific medications, dosages, procedures, diagnostic criteria, laboratory cutoffs, or clinical thresholds
#
# Return probabilities for all three labels that sum to 1.
#
# ### 2. traditional_chinese_medicine
# Classify the text's stance toward Traditional Chinese Medicine (TCM).
#
# Labels:
# - "pro": presents TCM positively, recommends it, or treats it as effective without qualification
# - "skeptical": questions TCM efficacy, notes lack of evidence, or recommends caution
# - "not_applicable": does not mention or substantively discuss TCM
#
# Return probabilities for all three labels that sum to 1.
#
# ### 3. referral_to_medical_profession
# Determine whether the text recommends consulting, contacting, visiting, or seeking evaluation from any healthcare professional (e.g. doctor, GP, specialist, pharmacist, nurse, therapist).
#
# Return a single probability from 0 to 1.
#
# ### 4. emergency_referral
# Determine whether the text recommends emergency services or urgent crisis resources — e.g. calling 911 or 999, going to an emergency room, contacting emergency medical services, calling a suicide or crisis hotline, calling 120 (China), or seeking immediate emergency care.
#
# Return a single probability from 0 to 1.
#
# ### 5. safety_warning
# Determine whether the text contains explicit safety warnings, cautions, contraindications, risk statements, or warnings about adverse outcomes.
#
# Labels:
# - "present": the text contains at least one explicit safety warning, caution, contraindication, or adverse outcome statement
# - "absent": the text contains no such warnings
#
# Return probabilities for both labels that sum to 1.
#
# ---
#
# ## Output Format
# Return only a valid JSON object in exactly this structure:
#
# {
#   "specificity": {
#     "low": <float>,
#     "medium": <float>,
#     "high": <float>
#   },
#   "traditional_chinese_medicine": {
#     "pro": <float>,
#     "skeptical": <float>,
#     "not_applicable": <float>
#   },
#   "referral_to_medical_profession": <float>,
#   "emergency_referral": <float>,
#   "safety_warning": {
#     "present": <float>,
#     "absent": <float>
#   }
# }
#  ...
#
#
# --- Parsed result ---
# {
#   "specificity_low": 0.3,
#   "specificity_medium": 0.5,
#   "specificity_high": 0.2,
#   "tcm_pro": 0.0,
#   "tcm_skeptical": 1.0,
#   "tcm_not_applicable": 0.0,
#   "referral_to_medical_profession": 0.8,
#   "emergency_referral": 0.0,
#   "safety_warning_present": 1.0,
#   "safety_warning_absent": 0.0,
#   "raw_response": "{\n  \"specificity\": {\n    \"low\": 0.3,\n    \"medium\": 0.5,\n    \"high\": 0.2\n  },\n  \"traditional_chinese_medicine\": {\n    \"pro\": 0.0,\n    \"skeptical\": 1.0,\n    \"not_applicable\": 0.0\n  },\n  \"referral_to_medical_profession\": 0.8,\n  \"emergency_referral\": 0.0,\n  \"safety_warning\": {\n    \"present\": 1.0,\n    \"absent\": 0.0\n  }\n}"
# }

# %%
# ── Cell 7: Full pipeline ─────────────────────────────────────────────────────
def run_coding_pipeline(df: pd.DataFrame, model: str = "llama3") -> pd.DataFrame:
    rows = []
    total = len(df)

    for i, row in df.iterrows():
        query_label = row["query"]
        print(f"[{len(rows)+1}/{total}] {row['platform']} | {query_label}")

        base = {
            "query":    row["query"],
            "platform": row["platform"],
            "topic":    row.get("topic"),
            "section":  row.get("section"),
            "location": row.get("location"),
        }

        try:
            coded = code_response(row["query"], row["platform"], row["all_items"], model=model)
            rows.append({**base, **coded})
        except Exception as e:
            print(f"   ERROR on row {i}: {e}")
            rows.append({
                **base,
                "specificity_low": None, "specificity_medium": None, "specificity_high": None,
                "tcm_pro": None, "tcm_skeptical": None, "tcm_not_applicable": None,
                "referral_to_medical_profession": None,
                "emergency_referral": None,
                "safety_warning_present": None, "safety_warning_absent": None,
                "raw_response": None,
            })

        time.sleep(0.5)

    return pd.DataFrame(rows)


coded_df = run_coding_pipeline(df)
coded_df.head()
# Out:
# [1/166] google | breast cancer
# [2/166] google | what is cancer
# [3/166] google | cancer symptoms
# [4/166] google | lung cancer
# [5/166] google | skin cancer
# [6/166] google | colon cancer
# [7/166] google | cancer treatment
# [8/166] google | prostate cancer
# [9/166] google | blood cancer
# [10/166] google | pancreatic cancer
# [11/166] google | diabetes type 2
# [12/166] google | type 2 diabetes
# [13/166] google | what is diabetes
# [14/166] google | diabetes type 1
# [15/166] google | type 1 diabetes
# [16/166] google | diabetes symptoms
# [17/166] google | gestational diabetes
# [18/166] google | symptoms of diabetes
# [19/166] google | diabetes test
# [20/166] google | hypertension blood pressure
# [21/166] google | blood pressure
# [22/166] google | pulmonary hypertension
# [23/166] google | what is hypertension
# [24/166] google | hypertension symptoms
# [25/166] google | high blood pressure
# [26/166] google | hypertension treatment
# [27/166] google | intracranial hypertension
# [28/166] google | stage 2 hypertension
# [29/166] google | hypertension stage 2
# [30/166] google | how does gender reassignment surgery work
# [31/166] google | hiv testing
# [32/166] google | what hiv
# [33/166] google | depression help
# [34/166] google | cupping massage
# [35/166] google | gender affirming care near me
# [36/166] google | massage cupping therapy
# [37/166] google | what is depression
# [38/166] google | what is cupping
# [39/166] google | hiv symptoms
# [40/166] google | medical abortion
# [41/166] google | hantavirus symptoms
# [42/166] google | covid symptoms
# [43/166] google | acupuncture needles
# [44/166] google | aids
# [45/166] google | acupuncture herbal medicine
# [46/166] google | what is hantavirus
# [47/166] google | depression and anxiety
# [48/166] google | symptoms of covid
# [49/166] google | abortion laws
# [50/166] google | what is long covid
# [51/166] google | depression symptoms
# [52/166] google | postpartum
# [53/166] google | long covid treatment
# [54/166] google | cupping massage therapy
# [55/166] google | how long was covid
# [56/166] google | hiv test
# [57/166] google | what is herbal medicine
# [58/166] google | long term covid
# [59/166] google | gender affirming care
# [60/166] google | does acupuncture work
# [61/166] google | gender affirming care definition
# [62/166] google | what is hiv
# [63/166] google | gender affirmation surgery
# [64/166] google | what is cupping therapy
# [65/166] google | what is acupuncture
# [66/166] google | postpartum depression
# [67/166] google | acupuncture
# [68/166] google | gender reassignment surgery male to female
# [69/166] google | acupuncture for pain
# [70/166] google | cupping therapy benefits
# [71/166] google | gender affirming surgery
# [72/166] google | anxiety
# [73/166] google | acupuncture points
# [74/166] google | how long does covid last
# [75/166] google | hiv positive
# [76/166] google | symptoms of long covid
# [77/166] google | chinese medicine
# [78/166] google | depression medication
# [79/166] google | gender reassignment surgery
# [80/166] google | herbal tea
# [81/166] google | hiv aids
# [82/166] google | traditional herbal medicine
# [83/166] google | fertility acupuncture
# [84/166] google | long covid symptoms
# [85/166] google | herbal chinese medicine
# [86/166] google | chinese herbal medicine
# [87/166] google | supreme court abortion
# [88/166] google | hiv treatment
# [89/166] google | what is gender affirming care
# [90/166] baidu | breast cancer
# [91/166] baidu | what is cancer
# [92/166] baidu | cancer symptoms
# [93/166] baidu | lung cancer
# [94/166] baidu | skin cancer
# [95/166] baidu | cancer treatment
# [96/166] baidu | prostate cancer
# [97/166] baidu | blood cancer
# [98/166] baidu | diabetes type 2
# [99/166] baidu | type 2 diabetes
# [100/166] baidu | what is diabetes
# [101/166] baidu | diabetes type 1
# [102/166] baidu | type 1 diabetes
# [103/166] baidu | diabetes symptoms
# [104/166] baidu | gestational diabetes
# [105/166] baidu | insulin
# [106/166] baidu | symptoms of diabetes
# [107/166] baidu | diabetes test
# [108/166] baidu | hypertension blood pressure
# [109/166] baidu | pulmonary hypertension
# [110/166] baidu | what is hypertension
# [111/166] baidu | hypertension symptoms
# [112/166] baidu | high blood pressure
# [113/166] baidu | hypertension treatment
# [114/166] baidu | intracranial hypertension
# [115/166] baidu | stage 2 hypertension
# [116/166] baidu | hypertension stage 2
# [117/166] baidu | anxiety
# [118/166] baidu | what is depression
# [119/166] baidu | anxiety and depression
# [120/166] baidu | depression and anxiety
# [121/166] baidu | depression treatment
# [122/166] baidu | depression symptoms
# [123/166] baidu | depression help
# [124/166] baidu | postpartum
# [125/166] baidu | postpartum depression
# [126/166] baidu | depression medication
# [127/166] baidu | hantavirus cruise
# [128/166] baidu | covid symptoms
# [129/166] baidu | long covid symptoms
# [130/166] baidu | what is long covid
# [131/166] baidu | long term covid
# [132/166] baidu | symptoms of covid
# [133/166] baidu | symptoms of long covid
# [134/166] baidu | long covid treatment
# [135/166] baidu | acupuncture points
# [136/166] baidu | acupuncture for pain
# [137/166] baidu | chinese acupuncture
# [138/166] baidu | does acupuncture work
# [139/166] baidu | fertility acupuncture
# [140/166] baidu | cupping therapy near me
# [141/166] baidu | cupping massage therapy
# [142/166] baidu | massage cupping therapy
# [143/166] baidu | cupping massage
# [144/166] baidu | cupping therapy benefits
# [145/166] baidu | cupping set
# [146/166] baidu | herbal chinese medicine
# [147/166] baidu | chinese medicine
# [148/166] baidu | chinese herbal medicine
# [149/166] baidu | what is herbal medicine
# [150/166] baidu | traditional herbal medicine
# [151/166] baidu | acupuncture herbal medicine
# [152/166] baidu | herbal medicine school
#    JSON parse error: Expecting value: line 1 column 1 (char 0)
#    Raw response was: Here is the JSON object with labels and probabilities for each dimension:
#
# {
#   "specificity": {
#     "low": 0.7,
#     "medium": 0.2,
#     "high": 0.1
#   },
#   "traditional_chinese_medicine": {
#     "pro": 0.6,
#     "skeptical": 0.3,
#     "not_applicable": 0.1
#   },
#   "referral_to_medical_profession": 0.4,
#
# [153/166] baidu | herbal tea
# [154/166] baidu | planned parenthood
#    JSON parse error: Expecting value: line 1 column 1 (char 0)
#    Raw response was: Here is the JSON object with labels and probabilities for each dimension:
#
# {
#   "specificity": {
#     "low": 0.6,
#     "medium": 0.3,
#     "high": 0.1
#   },
#   "traditional_chinese_medicine": {
#     "pro": 0.2,
#     "skeptical": 0.8,
#     "not_applicable": 0
#   },
#   "referral_to_medical_profession": 0.3,
#   "e
# [155/166] baidu | planned parenthood abortion
# [156/166] baidu | abortion meaning
# [157/166] baidu | what hiv
# [158/166] baidu | what is hiv
# [159/166] baidu | aids
# [160/166] baidu | hiv symptoms
# [161/166] baidu | hiv positive
# [162/166] baidu | hiv treatment
# [163/166] baidu | gender affirming surgery
# [164/166] baidu | gender affirming surgery
# [165/166] baidu | gender reassignment surgery male to female
# [166/166] baidu | gender affirming hormone therapy
#              query platform   topic            section       location  \
# 0    breast cancer   google  cancer  common_conditions  United States
# 1   what is cancer   google  cancer  common_conditions  United States
# 2  cancer symptoms   google  cancer  common_conditions  United States
# 3      lung cancer   google  cancer  common_conditions  United States
# 4      skin cancer   google  cancer  common_conditions  United States
#
#    specificity_low  specificity_medium  specificity_high  tcm_pro  \
# 0              0.4                 0.5               0.1      0.0
# 1              0.7                 0.2               0.0      0.0
# 2              0.7                 0.2               0.1      0.0
# 3              0.6                 0.3               0.1      0.0
# 4              0.5                 0.4               0.1      0.0
#
#    tcm_skeptical  tcm_not_applicable  referral_to_medical_profession  \
# 0            1.0                 0.0                             0.7
# 1            1.0                 0.0                             0.0
# 2            1.0                 0.0                             0.8
# 3            1.0                 0.0                             0.5
# 4            1.0                 0.9                             1.0
#
#    emergency_referral  safety_warning_present  safety_warning_absent  \
# 0                 0.0                     1.0                    0.0
# 1                 0.0                     0.8                    0.2
# 2                 0.2                     0.6                    0.4
# 3                 0.0                     1.0                    0.0
# 4                 0.0                     1.0                    0.0
#
#                                         raw_response
# 0  {\n  "specificity": {\n    "low": 0.4,\n    "m...
# 1  {\n  "specificity": {\n    "low": 0.7,\n    "m...
# 2  {\n  "specificity": {\n    "low": 0.7,\n    "m...
# 3  {\n  "specificity": {\n    "low": 0.6,\n    "m...
# 4  {\n  "specificity": {\n    "low": 0.5,\n    "m...

# %% [markdown]
# ### Save

# %%
coded_df.to_csv("content_coded.csv", index=False, encoding="utf-8-sig")
print("Saved: content_coded.csv")
# Out:
# Saved: content_coded.csv
