# %%
import serpapi
import json
import requests
import pandas as pd
import time

# %% [markdown]
# ### One call

# %%
api_key = "cae0d822c2848a3edc91a6fe613ab32ec3ad5f7e3769490a7f5e20c8b84a24ea"
api_key2 = ""

# %% [markdown]
# ### Functions

# %%
def query_serpapi(location, search_query: str, api_key: str) -> dict:
    client = serpapi.Client(api_key=api_key)

    results = client.search({
        "q": search_query,
        "location": location,
        "hl": "en",
        "gl": "us",
        "google_domain": "google.com"
    })
    
    return results

# %%
def resolve_refs(indexes: list, ref_lookup: dict) -> list:
    """Map reference_indexes back to actual source metadata."""
    return [
        ref_lookup[i]
        for i in indexes
        if i in ref_lookup
    ]
def parse_ai_overview(ai_overview: dict) -> dict:

    ref_lookup = {
        ref["index"]: {
            "title": ref.get("title", ""),
            "link": ref.get("link", ""),
            "source": ref.get("source", "")
        }
        for ref in ai_overview.get("references", [])
    }

    parsed_sections = []

    for block in ai_overview.get("text_blocks", []):
        block_type = block.get("type")

        if block_type == "paragraph":
            parsed_sections.append({
                "type": "paragraph",
                "content": block.get("snippet", ""),
                "cited_sources": resolve_refs(block.get("reference_indexes", []), ref_lookup)
            })

        elif block_type == "list":
            items = [item.get("snippet", "") for item in block.get("list", [])]
            parsed_sections.append({
                "type": "list",
                "items": items,
                "cited_sources": resolve_refs(block.get("reference_indexes", []), ref_lookup)
            })

    return {
        "sections": parsed_sections,
        "all_references": list(ref_lookup.values())
    }

# %%
def extract_paa(serpapi_response: dict) -> list:
    """Extract People Also Ask questions — great seed for new queries."""
    return [
        item.get("question", "")
        for item in serpapi_response.get("related_questions", [])
    ]

# %% [markdown]
# ### Loop through queries

# %%
queries = [
    "breast cancer",
    "what is cancer",
    "cancer symptoms",
    "lung cancer",
    "skin cancer",
    "colon cancer",
    "cancer treatment",
    "prostate cancer",
    "blood cancer",
    "pancreatic cancer",
    "diabetes type 2",
    "type 2 diabetes",
    "what is diabetes",
    "diabetes type 1",
    "type 1 diabetes",
    "diabetes symptoms",
    "gestational diabetes",
    "insulin",
    "symptoms of diabetes",
    "diabetes test",
    "hypertension blood pressure",
    "blood pressure",
    "pulmonary hypertension",
    "what is hypertension",
    "hypertension symptoms",
    "high blood pressure",
    "hypertension treatment",
    "intracranial hypertension",
    "stage 2 hypertension",
    "hypertension stage 2",
]

# %%
def run_pipeline_for_queries(queries, api_key, locations) -> pd.DataFrame:
    rows = []
    total = len(queries) * len(locations)
    counter = 0

    for location in locations:
        for i, query in enumerate(queries):
            counter += 1
            print(f"[{counter}/{total}] Location: '{location}' | Query: '{query}'")
            
            try:
                # 1. Hit SerpAPI
                results = query_serpapi(location, query, api_key)
                
                # 2. Extract AI Overview
                ai_overview_raw = results.get("ai_overview")
                
                # 3. Extract PAA
                paa = extract_paa(results)
                
                if not ai_overview_raw:
                    rows.append({
                        "location": location,
                        "query": query,
                        "has_ai_overview": False,
                        "all_items": None,
                        "cited_sources": None,
                        "all_references": None,
                        "paa_questions": paa
                        
                    })
                    continue

                # 4. Parse AI Overview
                parsed = parse_ai_overview(ai_overview_raw)

                # 5. Flatten all sections into one row
                all_items = []
                all_sources = []

                for section in parsed["sections"]:
                    if section["type"] == "list":
                        all_items.extend(section.get("items", []))
                    all_sources.extend(section.get("cited_sources", []))

                # Deduplicate sources
                seen = set()
                unique_sources = []
                for s in all_sources:
                    if s["link"] not in seen:
                        seen.add(s["link"])
                        unique_sources.append(s)

                rows.append({
                    "location": location,
                    "query": query,
                    "has_ai_overview": True,
                    "all_items": all_items,
                    "cited_sources": unique_sources,
                    "all_references": parsed["all_references"],
                    "paa_questions": paa
                })

            except Exception as e:
                print(f"   ERROR on '{query}' @ '{location}': {e}")
                rows.append({
                    "location": location,
                    "query": query,
                    "has_ai_overview": False,
                    "all_items": None,
                    "cited_sources": None,
                    "all_references": None,
                    "paa_questions": None
                })

            time.sleep(1.5)

    return pd.DataFrame(rows)

# %%
df = run_pipeline_for_queries(queries, api_key, locations = ['United States'])

print(f"\nTotal rows: {len(df)}")
print(f"Queries with AI Overview: {df['has_ai_overview'].sum()}")
print(f"Queries without AI Overview: {(~df['has_ai_overview']).sum()}")
df.head()
# Out:
# [1/30] Location: 'United States' | Query: 'breast cancer'
# [2/30] Location: 'United States' | Query: 'what is cancer'
# [3/30] Location: 'United States' | Query: 'cancer symptoms'
# [4/30] Location: 'United States' | Query: 'lung cancer'
# [5/30] Location: 'United States' | Query: 'skin cancer'
# [6/30] Location: 'United States' | Query: 'colon cancer'
# [7/30] Location: 'United States' | Query: 'cancer treatment'
# [8/30] Location: 'United States' | Query: 'prostate cancer'
# [9/30] Location: 'United States' | Query: 'blood cancer'
# [10/30] Location: 'United States' | Query: 'pancreatic cancer'
# [11/30] Location: 'United States' | Query: 'diabetes type 2'
# [12/30] Location: 'United States' | Query: 'type 2 diabetes'
# [13/30] Location: 'United States' | Query: 'what is diabetes'
# [14/30] Location: 'United States' | Query: 'diabetes type 1'
# [15/30] Location: 'United States' | Query: 'type 1 diabetes'
# [16/30] Location: 'United States' | Query: 'diabetes symptoms'
# [17/30] Location: 'United States' | Query: 'gestational diabetes'
# [18/30] Location: 'United States' | Query: 'insulin'
# [19/30] Location: 'United States' | Query: 'symptoms of diabetes'
# [20/30] Location: 'United States' | Query: 'diabetes test'
# [21/30] Location: 'United States' | Query: 'hypertension blood pressure'
# [22/30] Location: 'United States' | Query: 'blood pressure'
# [23/30] Location: 'United States' | Query: 'pulmonary hypertension'
# [24/30] Location: 'United States' | Query: 'what is hypertension'
# [25/30] Location: 'United States' | Query: 'hypertension symptoms'
# [26/30] Location: 'United States' | Query: 'high blood pressure'
# [27/30] Location: 'United States' | Query: 'hypertension treatment'
# [28/30] Location: 'United States' | Query: 'intracranial hypertension'
# [29/30] Location: 'United States' | Query: 'stage 2 hypertension'
# [30/30] Location: 'United States' | Query: 'hypertension stage 2'
#
# Total rows: 30
# Queries with AI Overview: 29
# Queries without AI Overview: 1
#         location            query  has_ai_overview  \
# 0  United States    breast cancer             True
# 1  United States   what is cancer             True
# 2  United States  cancer symptoms             True
# 3  United States      lung cancer             True
# 4  United States      skin cancer             True
#
#                                            all_items  \
# 0  [A new lump or mass in the breast or underarm ...
# 1  [Tumor Formation: Extra cells form masses of t...
# 2  [Unexplained Weight Loss: Losing $\ge 10$ poun...
# 3  [Non-Small Cell Lung Cancer (NSCLC): Accounts ...
# 4  [Basal Cell Carcinoma (BCC): The most common t...
#
#                                        cited_sources  \
# 0  [{'title': 'Breast cancer - World Health Organ...
# 1  [{'title': 'What Is Cancer? Symptoms, Causes &...
# 2  [{'title': 'Cancer - Symptoms and causes - May...
# 3  [{'title': 'Lung cancer - World Health Organiz...
# 4  [{'title': 'Skin Cancer Basics - CDC', 'link':...
#
#                                       all_references  \
# 0  [{'title': 'Breast cancer - Symptoms and cause...
# 1  [{'title': 'What Is Cancer? - NCI - National C...
# 2  [{'title': 'Cancer - Symptoms and causes - May...
# 3  [{'title': 'What Is Lung Cancer? | Types of Lu...
# 4  [{'title': 'Skin cancer - Symptoms and causes ...
#
#                                        paa_questions
# 0  [What are the top 3 signs of breast cancer?, W...
# 1  [What is the simple definition of cancer?, Wha...
# 2  [What are the 7 warning signs for cancer?, Wha...
# 3  [How long can you live with one lung cancer?, ...
# 4  [What does skin cancer look like when it just ...

# %%
df
# Out:
#          location                        query  has_ai_overview  \
# 0   United States                breast cancer             True
# 1   United States               what is cancer             True
# 2   United States              cancer symptoms             True
# 3   United States                  lung cancer             True
# 4   United States                  skin cancer             True
# 5   United States                 colon cancer             True
# 6   United States             cancer treatment             True
# 7   United States              prostate cancer             True
# 8   United States                 blood cancer             True
# 9   United States            pancreatic cancer             True
# 10  United States              diabetes type 2             True
# 11  United States              type 2 diabetes             True
# 12  United States             what is diabetes             True
# 13  United States              diabetes type 1             True
# 14  United States              type 1 diabetes             True
# 15  United States            diabetes symptoms             True
# 16  United States         gestational diabetes             True
# 17  United States                      insulin            False
# 18  United States         symptoms of diabetes             True
# 19  United States                diabetes test             True
# 20  United States  hypertension blood pressure             True
# 21  United States               blood pressure             True
# 22  United States       pulmonary hypertension             True
# 23  United States         what is hypertension             True
# 24  United States        hypertension symptoms             True
# 25  United States          high blood pressure             True
# 26  United States       hypertension treatment             True
# 27  United States    intracranial hypertension             True
# 28  United States         stage 2 hypertension             True
# 29  United States         hypertension stage 2             True
#
#                                             all_items  \
# 0   [A new lump or mass in the breast or underarm ...
# 1   [Tumor Formation: Extra cells form masses of t...
# 2   [Unexplained Weight Loss: Losing $\ge 10$ poun...
# 3   [Non-Small Cell Lung Cancer (NSCLC): Accounts ...
# 4   [Basal Cell Carcinoma (BCC): The most common t...
# 5   [When to start: Average-risk individuals shoul...
# 6                                                  []
# 7   [Trouble starting urination or a weak/interrup...
# 8   [Leukemia: Starts in the bone marrow and blood...
# 9                                                  []
# 10  [Increased thirst and frequent urination, Unex...
# 11  [Increased thirst and frequent urination, Unex...
# 12  [When you eat, your body breaks down carbohydr...
# 13  [Cause: The immune system mistakenly attacks t...
# 14  [Extreme thirst and frequent urination, Uninte...
# 15  [Frequent Urination (Polyuria): Urinating ofte...
# 16  [When it occurs: Typically diagnosed in the se...
# 17                                               None
# 18  [Frequent Urination (Polyuria): Urinating ofte...
# 19  [What it does: Measures your average blood sug...
# 20  [Normal: Less than $120/80$, Elevated: $120\te...
# 21  [Elevated/Stage 1/Stage 2: Do not panic over a...
# 22  [Shortness of breath (initially during exertio...
# 23  [Systolic (Top number): The pressure when your...
# 24  [Severe headaches, Shortness of breath, Vision...
# 25  [Normal: Below 120/80 mmHg, Elevated: 120–129 ...
# 26  [Dietary Changes: Adopt a heart-healthy diet (...
# 27  [Idiopathic Intracranial Hypertension (IIH): A...
# 28  [Stage 2 Hypertension: $\ge 140$ mmHg (systoli...
# 29  [Stage 2 Hypertension: $\ge 140$ mmHg (systoli...
#
#                                         cited_sources  \
# 0   [{'title': 'Breast cancer - World Health Organ...
# 1   [{'title': 'What Is Cancer? Symptoms, Causes &...
# 2   [{'title': 'Cancer - Symptoms and causes - May...
# 3   [{'title': 'Lung cancer - World Health Organiz...
# 4   [{'title': 'Skin Cancer Basics - CDC', 'link':...
# 5   [{'title': 'Colorectal Cancer Alliance | Preve...
# 6                                                  []
# 7   [{'title': 'Prostate cancer - Symptoms and cau...
# 8   [{'title': 'Blood Cancer: Types, Symptoms, Tre...
# 9                                                  []
# 10  [{'title': 'Type 2 Diabetes - NIDDK', 'link': ...
# 11  [{'title': 'Type 2 Diabetes - NIDDK', 'link': ...
# 12  [{'title': 'What Is Diabetes? - NIDDK', 'link'...
# 13  [{'title': 'Type 1 Diabetes: What It Is, Cause...
# 14  [{'title': 'Understanding Type 1 Diabetes | AD...
# 15  [{'title': 'Diabetes - Symptoms and causes - M...
# 16  [{'title': 'Gestational Diabetes - CDC', 'link...
# 17                                               None
# 18  [{'title': 'Diabetes - Symptoms and causes - M...
# 19  [{'title': 'Diabetes Testing & Management | Mi...
# 20  [{'title': 'High blood pressure (hypertension)...
# 21  [{'title': 'Understanding Blood Pressure Readi...
# 22  [{'title': 'Guide to Pulmonary Hypertension - ...
# 23  [{'title': 'High blood pressure (hypertension)...
# 24  [{'title': '9 Surprisingly Subtle Symptoms of ...
# 25  [{'title': 'What is High Blood Pressure? | Ame...
# 26  [{'title': 'Hypertension (High Blood Pressure)...
# 27  [{'title': 'Idiopathic Intracranial Hypertensi...
# 28  [{'title': 'Life’s Essential 8 - How to Manage...
# 29  [{'title': 'Life’s Essential 8 - How to Manage...
#
#                                        all_references  \
# 0   [{'title': 'Breast cancer - Symptoms and cause...
# 1   [{'title': 'What Is Cancer? - NCI - National C...
# 2   [{'title': 'Cancer - Symptoms and causes - May...
# 3   [{'title': 'What Is Lung Cancer? | Types of Lu...
# 4   [{'title': 'Skin cancer - Symptoms and causes ...
# 5   [{'title': 'Colon cancer - Symptoms and causes...
# 6                                                  []
# 7   [{'title': 'Prostate cancer - Symptoms and cau...
# 8   [{'title': 'Blood Cancer: Types, Symptoms, Tre...
# 9                                                  []
# 10  [{'title': 'Type 2 diabetes - Symptoms and cau...
# 11  [{'title': 'Type 2 diabetes - Symptoms and cau...
# 12  [{'title': 'What Is Diabetes? - NIDDK', 'link'...
# 13  [{'title': 'Type 1 diabetes - Symptoms and cau...
# 14  [{'title': 'Understanding Type 1 Diabetes | AD...
# 15  [{'title': 'Diabetes - Symptoms and causes - M...
# 16  [{'title': 'Gestational diabetes - Symptoms & ...
# 17                                               None
# 18  [{'title': 'Diabetes - Symptoms and causes - M...
# 19  [{'title': '60-Second Risk Test for Type 2 Dia...
# 20  [{'title': 'High blood pressure (hypertension)...
# 21  [{'title': 'Understanding Blood Pressure Readi...
# 22  [{'title': 'Pulmonary hypertension - Symptoms ...
# 23  [{'title': 'High blood pressure (hypertension)...
# 24  [{'title': 'High blood pressure (hypertension)...
# 25  [{'title': 'What is High Blood Pressure? | Ame...
# 26  [{'title': 'High blood pressure (hypertension)...
# 27  [{'title': 'Idiopathic Intracranial Hypertensi...
# 28  [{'title': 'Understanding Blood Pressure Readi...
# 29  [{'title': 'Understanding Blood Pressure Readi...
#
#                                         paa_questions
# 0   [What are the top 3 signs of breast cancer?, W...
# 1   [What is the simple definition of cancer?, Wha...
# 2   [What are the 7 warning signs for cancer?, Wha...
# 3   [How long can you live with one lung cancer?, ...
# 4   [What does skin cancer look like when it just ...
# 5   [What is the survival rate for colon cancer?, ...
# 6   [What are the top 3 treatments for cancer?, Wh...
# 7   [What are the 5 warning signs of prostate canc...
# 8   [Is cancer in the blood curable?, Can you surv...
# 9   [How long does pancreatic cancer take to devel...
# 10  [What happens if you have type 2 diabetes?, Wh...
# 11  [What happens when you have diabetes type 2?, ...
# 12  [What causes your diabetes?, What are 5 sympto...
# 13  [Can a person with type 1 diabetes live a norm...
# 14  [What is a type 1 diabetic?, Can a type 1 diab...
# 15  [What are the 10 early signs of diabetes?, How...
# 16  [What can cause gestational diabetes?, When is...
# 17  [What is the bedtime trick for diabetes?, What...
# 18  [What are 5 early warning signs of diabetes?, ...
# 19  [What are 10 warning signs of diabetes?, What ...
# 20  [What are 5 signs of hypertension?, What are t...
# 21  [What is a normal blood pressure reading?, Wha...
# 22  [What is the first line treatment for pulmonar...
# 23  [What are 5 signs of hypertension?, What is th...
# 24  [What are 5 signs of hypertension?, What are t...
# 25  [How can I bring my blood pressure down fast?,...
# 26  [What is the best treatment for hypertension?,...
# 27  [What does an intracranial hypertension headac...
# 28  [How serious is stage 2 hypertension?, Is hype...
# 29  [How can I lower my stage 2 hypertension?, Is ...

# %%
file_name = "common_google.csv"

df.to_csv(file_name, index=False) 
print("Saved to", file_name)
# Out:
# Saved to common_google.csv
